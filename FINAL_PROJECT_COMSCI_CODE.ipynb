# %% [markdown]
# <a href="https://colab.research.google.com/github/jacynthpajarito-hash/GROUP4CODE_BMICALCPROGRARM_MASSINDEX/blob/main/FINAL_PROJECT_COMSCI_CODE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_bmi():
    while True:
        try:
            print("\n--- BMI Calculator ---")
            # 1
            weight = float(input("Enter your weight in kg: "))
            height = float(input("Enter your height in meters (e.g., 1.75): "))


            bmi = weight / (height ** 2)
            print(f"Your BMI is: {bmi:.2f}")


            if bmi < 18.5:
                category = "Underweight"
            elif 18.5 <= bmi < 25:
                category = "Normal (Healthy Weight)"
            elif 25 <= bmi < 30:
                category = "Overweight"
            else:
                category = "Obese"

            print(f"Category: {category}")

        except ValueError:
            print("Invalid input. Please enter numerical values for weight and height.")
        except ZeroDivisionError:
            print("Height cannot be zero.")


        choice = input("\nCalculate another? (y/n): ").lower()
        if choice != 'y':
            print("Exiting. Goodbye!")
            break


if __name__ == "__main__":
    calculate_bmi()
# Out:
# --- BMI Calculator ---
# Enter your weight in kg: 55
# Enter your height in meters (e.g., 1.75): 1.50
# Your BMI is: 24.44
# Category: Normal (Healthy Weight)
#
# Calculate another? (y/n): n
# Exiting. Goodbye!
